# %%
from everycheese.cheeses.tests.factories import CheeseFactory

# %%
for x in range(10):
    CheeseFactory(name=f"Sample Cheese {x}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-5703189e29c8> in <module>
#       1 for x in range(10):
# ----> 2     CheeseFactory(name=f"Sample Cheese {x}")
#
# /opt/ENTER/lib/python3.7/site-packages/factory/base.py in __call__(cls, **kwargs)
#      44             return cls.build(**kwargs)
#      45         elif cls._meta.strategy == enums.CREATE_STRATEGY:
# ---> 46             return cls.create(**kwargs)
#      47         elif cls._meta.strategy == enums.STUB_STRATEGY:
#      48             return cls.stub(**kwargs)
#
# /opt/ENTER/lib/python3.7/site-packages/factory/base.py in create(cls, **kwargs)
#     562     def create(cls, **kwargs):
#     563         """Create an instance of the associated class, with overriden attrs."""
# --> 564         return cls._generate(enums.CREATE_STRATEGY, kwargs)
#     565
#     566     @classmethod
#
# /opt/ENTER/lib/python3.7/site-packages/factory/django.py in _generate(cls, strategy, params)
#     139         # object initially due to an IntegrityError being raised
#     140         cls._original_params = params
# --> 141         return super(DjangoModelFactory, cls)._generate(strategy, params)
#     142
#     143     @classmethod
#
# /opt/ENTER/lib/python3.7/site-packages/factory/base.py in _generate(cls, strategy, params)
#     499
#     500         step = builder.StepBuilder(cls._meta, params, strategy)
# --> 501         return step.build()
#     502
#     503     @classmethod
#
# /opt/ENTER/lib/python3.7/site-packages/factory/builder.py in build(self, parent_step, force_sequence)
#     270             parent_step=parent_step,
#     271         )
# --> 272         step.resolve(pre)
#     273
#     274         args, kwargs = self.factory_meta.prepare_arguments(step.attributes)
#
# /opt/ENTER/lib/python3.7/site-packages/factory/builder.py in resolve(self, declarations)
#     219
#     220         for field_name in declarations:
# --> 221             self.attributes[field_name] = getattr(self.stub, field_name)
#     222
#     223     @property
#
# /opt/ENTER/lib/python3.7/site-packages/factory/builder.py in __getattr__(self, name)
#     373                         instance=self,
#     374                         step=self.__step,
# --> 375                         extra=context,
#     376                     )
#     377                 finally:
#
# /opt/ENTER/lib/python3.7/site-packages/factory/faker.py in evaluate(self, instance, step, extra)
#      54
#      55     def evaluate(self, instance, step, extra):
# ---> 56         return self.generate(extra)
#      57
#      58     _FAKER_REGISTRY = {}
#
# /opt/ENTER/lib/python3.7/site-packages/factory/faker.py in generate(self, extra_kwargs)
#      51         kwargs.update(extra_kwargs or {})
#      52         subfaker = self._get_faker(self.locale)
# ---> 53         return subfaker.format(self.provider, **kwargs)
#      54
#      55     def evaluate(self, instance, step, extra):
#
# /opt/ENTER/lib/python3.7/site-packages/faker/generator.py in format(self, formatter, *args, **kwargs)
#      73         """
#      74         # TODO: data export?
# ---> 75         return self.get_formatter(formatter)(*args, **kwargs)
#      76
#      77     def get_formatter(self, formatter):
#
# TypeError: paragraph() got an unexpected keyword argument 'variable_nb_sentency'

# %%
for x in range(10):
    CheeseFactory(name=f"Sample Cheese {x}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-5703189e29c8> in <module>
#       1 for x in range(10):
# ----> 2     CheeseFactory(name=f"Sample Cheese {x}")
#
# /opt/ENTER/lib/python3.7/site-packages/factory/base.py in __call__(cls, **kwargs)
#      44             return cls.build(**kwargs)
#      45         elif cls._meta.strategy == enums.CREATE_STRATEGY:
# ---> 46             return cls.create(**kwargs)
#      47         elif cls._meta.strategy == enums.STUB_STRATEGY:
#      48             return cls.stub(**kwargs)
#
# /opt/ENTER/lib/python3.7/site-packages/factory/base.py in create(cls, **kwargs)
#     562     def create(cls, **kwargs):
#     563         """Create an instance of the associated class, with overriden attrs."""
# --> 564         return cls._generate(enums.CREATE_STRATEGY, kwargs)
#     565
#     566     @classmethod
#
# /opt/ENTER/lib/python3.7/site-packages/factory/django.py in _generate(cls, strategy, params)
#     139         # object initially due to an IntegrityError being raised
#     140         cls._original_params = params
# --> 141         return super(DjangoModelFactory, cls)._generate(strategy, params)
#     142
#     143     @classmethod
#
# /opt/ENTER/lib/python3.7/site-packages/factory/base.py in _generate(cls, strategy, params)
#     499
#     500         step = builder.StepBuilder(cls._meta, params, strategy)
# --> 501         return step.build()
#     502
#     503     @classmethod
#
# /opt/ENTER/lib/python3.7/site-packages/factory/builder.py in build(self, parent_step, force_sequence)
#     270             parent_step=parent_step,
#     271         )
# --> 272         step.resolve(pre)
#     273
#     274         args, kwargs = self.factory_meta.prepare_arguments(step.attributes)
#
# /opt/ENTER/lib/python3.7/site-packages/factory/builder.py in resolve(self, declarations)
#     219
#     220         for field_name in declarations:
# --> 221             self.attributes[field_name] = getattr(self.stub, field_name)
#     222
#     223     @property
#
# /opt/ENTER/lib/python3.7/site-packages/factory/builder.py in __getattr__(self, name)
#     373                         instance=self,
#     374                         step=self.__step,
# --> 375                         extra=context,
#     376                     )
#     377                 finally:
#
# /opt/ENTER/lib/python3.7/site-packages/factory/faker.py in evaluate(self, instance, step, extra)
#      54
#      55     def evaluate(self, instance, step, extra):
# ---> 56         return self.generate(extra)
#      57
#      58     _FAKER_REGISTRY = {}
#
# /opt/ENTER/lib/python3.7/site-packages/factory/faker.py in generate(self, extra_kwargs)
#      51         kwargs.update(extra_kwargs or {})
#      52         subfaker = self._get_faker(self.locale)
# ---> 53         return subfaker.format(self.provider, **kwargs)
#      54
#      55     def evaluate(self, instance, step, extra):
#
# /opt/ENTER/lib/python3.7/site-packages/faker/generator.py in format(self, formatter, *args, **kwargs)
#      73         """
#      74         # TODO: data export?
# ---> 75         return self.get_formatter(formatter)(*args, **kwargs)
#      76
#      77     def get_formatter(self, formatter):
#
# TypeError: paragraph() got an unexpected keyword argument 'variable_nb_sentency'
